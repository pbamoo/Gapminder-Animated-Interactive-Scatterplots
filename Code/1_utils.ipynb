# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)
pd.options.display.max_columns = None

# %% [markdown]
# ### Understanding the Data
# In this exercise we will reproduce Hans Rosling’s famous animation using the steps outlined below
# 1. We are going to read in 3 datasets obtained from http://www.gapminder.org/data :
#     * worldwide fertility rate data
#     * worldwide life expectancy data
#     * worldwide population data
#
#
# 2. Merge all the data into a single DataFrame.
#
# 3. Generate a scatterplot for a single year.
#
# 4. Combine images of scatterplots of all years to make an animation / gif.

# %%
# Read files
fert = pd.read_csv("../data/gapminder_total_fertility.csv", index_col=0)
population = pd.read_excel("../data/gapminder_population.xlsx", index_col = 0, engine='openpyxl')
life = pd.read_excel("../data/gapminder_lifeexpectancy.xlsx", index_col=0, engine='openpyxl')

# %%
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
population
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
# ...                          ...        ...        ...        ...        ...
# NaN                          NaN        NaN        NaN        NaN        NaN
# NaN                          NaN        NaN        NaN        NaN        NaN
# NaN                          NaN        NaN        NaN        NaN        NaN
# NaN                          NaN        NaN        NaN        NaN        NaN
# NaN                          NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# NaN                      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NaN                      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NaN                      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NaN                      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NaN                      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %% [markdown]
# We can immediately see from the three dataFrames above that there lot of missing data while the shapes aren't the same. The population dataFrame for instance captured data only decade wise from the 1800s to 1950 while the other 2 did so yearly. We are therefore going subset and work with year > 1950, do some preprocessing and merge all three dataFrames.

# %% [markdown]
# ### Preprocessing the Data
# * Transforming Dataframe
# * Handling NaNs

# %%
# Transform columns with dtype string to integer
fert.columns = fert.columns.astype(int)

# Rename index to 'country'
fert.index.name = 'country'
population.index.name = 'country'
life.index.name = 'country'

# Reset the index
fert = fert.reset_index()
population = population.reset_index()
life = life.reset_index()

# Convert the tables into long format, melt & merge
fert = fert.melt(id_vars='country', var_name='year', value_name='fertility_rate')
population = population.melt(id_vars='country', var_name='year', value_name='total_population')
life = life.melt(id_vars='country', var_name='year', value_name='life_expectancy')

df = fert.merge(population).merge(life)
df = df[ df.year >= 1950 ]
df.reset_index(drop=True, inplace=True)

print('\033[1m' + '\033[94m' + 'Table Schema and Data Types:'.center(80)+ '\033[0m')
print(df.info())
print('\n')
print('\033[1m' + '\033[94m' + 'Descriptive Statistics:'.center(80)+ '\033[0m')
print(df.describe())
print('\n')
missing_values = df.isnull().sum()
missing_per = (missing_values/df.shape[0])*100
missing_table = pd.concat([missing_values,missing_per], axis=1, ignore_index=True) 
missing_table.rename(columns={0:'Total Missing',1:'% Missing'}, inplace=True)
print('\033[1m' + '\033[94m' + 'Missing Data Info:'.center(80) + '\033[0m')
print(missing_table)
print('\n')

print('\033[1m' + '\033[94m' + 'DataFrame after Transformation:'.center(80)+ '\033[0m')
df
# Out:
#                           Table Schema and Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17094 entries, 0 to 17093
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           17094 non-null  object
#  1   year              17094 non-null  object
#  2   fertility_rate    13262 non-null  float64
#  3   total_population  16545 non-null  float64
#  4   life_expectancy   13443 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 667.9+ KB
# None
#
#
#                             Descriptive Statistics:
#        fertility_rate  total_population  life_expectancy
# count    13262.000000      1.654500e+04     13443.000000
# mean         4.290971      2.048369e+07        62.940251
# std          2.038273      8.830614e+07        11.842818
# min          0.840000      5.000000e+01        13.200000
# 25%          2.340000      1.738260e+05        54.800000
# ...

# %% [markdown]
# From the results above after the data transformations, it can be seen that there are missing data which needs to be dealt with which we will tackle below. Also we can make some interesting inferences from the descriptive statistics, e.g. min,max, percentiles of the total population and life expectancy. Now let's write that into a function we can call in the EDA script.

# %%
# def transform_data(df1,df2,df3):
#     # Transform columns with dtype string to integer
#     df1.columns = df1.columns.astype(int)

#     # Rename index to 'country'
#     df1.index.name = 'country'
#     df2.index.name = 'country'
#     df3.index.name = 'country'

#     # Reset the index
#     df1 = df1.reset_index()
#     df2 = df2.reset_index()
#     df3 = df3.reset_index()

#     # Convert the tables into long format, melt & merge
#     df1 = df1.melt(id_vars='country', var_name='year', value_name='fertility_rate')
#     df2 = df2.melt(id_vars='country', var_name='year', value_name='total_population')
#     df3 = df3.melt(id_vars='country', var_name='year', value_name='life_expectancy')

#     df = df1.merge(df2).merge(df3)
#     df = df[ df.year >= 1950 ]
#     df.reset_index(drop=True, inplace=True)

#     print('\033[1m' + '\033[94m' + 'Table Schema and Data Types:'.center(80)+ '\033[0m')
#     print(df.info())
#     print('\n')
#     print('\033[1m' + '\033[94m' + 'Descriptive Statistics:'.center(80)+ '\033[0m')
#     print(df.describe())
#     print('\n')
#     missing_values = df.isnull().sum()
#     missing_per = (missing_values/df.shape[0])*100
#     missing_table = pd.concat([missing_values,missing_per], axis=1, ignore_index=True) 
#     missing_table.rename(columns={0:'Total Missing',1:'% Missing'}, inplace=True)
#     print('\033[1m' + '\033[94m' + 'Missing Data Info:'.center(80) + '\033[0m')
#     print(missing_table)
#     print('\n')   
#     return df

# df = transform_data(fert,population,life)

# %%
# Drop the missing values
df = df.dropna()

print('\033[1m' + '\033[94m' + 'Missing Years'.center(80) + '\033[0m')
years = df['year'].unique()
missing_years = [y for y in range(min(years), max(years)+1) if y not in years]
print('missing_years=', missing_years)
print('\n')
missing_values = df.isnull().sum()
missing_per = (missing_values/df.shape[0])*100
missing_table = pd.concat([missing_values,missing_per], axis=1, ignore_index=True) 
missing_table.rename(columns={0:'Total Missing',1:'% Missing'}, inplace=True)
print('\033[1m' + '\033[94m' + 'Missing Data Info:'.center(80) + '\033[0m')
print(missing_table)
print('\n')
print('\033[1m' + '\033[94m' + 'DataFrame after dropping NaNs:'.center(80)+ '\033[0m')
df
# Out:
#                                  Missing Years
# missing_years= []
#
#
#                                Missing Data Info:
#                   Total Missing  % Missing
# country                       0        0.0
# year                          0        0.0
# fertility_rate                0        0.0
# total_population              0        0.0
# life_expectancy               0        0.0
#
#
#                          DataFrame after dropping NaNs:
#                      country  year  fertility_rate  total_population  \
# 1                Afghanistan  1950            7.67         7752118.0
# 3                    Albania  1950            5.80         1263171.0
# 4                    Algeria  1950            7.65         8872247.0
# 7                     Angola  1950            6.93         4354882.0
# 9        Antigua and Barbuda  1950            4.45           46301.0
# ...                      ...   ...             ...               ...
# ...

# %% [markdown]
# From the above, our dataFrame is now ready for visualization. Likewise, a function for missing data has also been writen and will be called from the 2_utils notebook.

# %%
# def missing_data(df):
    
#     # Options for filling NaNs(drop, Imputation using interpolation, ffill, bfill, mean, median, mode)
#     df = df.dropna()
    
#     missing_values = df.isnull().sum()
#     missing_per = (missing_values/df.shape[0])*100
#     missing_table = pd.concat([missing_values,missing_per], axis=1, ignore_index=True) 
#     missing_table.rename(columns={0:'Total Missing',1:'% Missing'}, inplace=True)
#     print('\033[1m' + '\033[94m' + 'Missing Data Info after dropna:'.center(80) + '\033[0m')
#     print(missing_table)
#     print('\n')   
#     return df

# df = missing_data(df)
