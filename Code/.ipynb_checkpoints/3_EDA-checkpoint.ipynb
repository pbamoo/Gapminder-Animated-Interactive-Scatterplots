# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("white")
import plotly_express as px
import imageio
from ipynb.fs.full.utils import transform_data, missing_data
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)
pd.options.display.max_columns = None

# %%
# Read files
fert = pd.read_csv("../data/gapminder_total_fertility.csv", index_col=0)
population = pd.read_excel("../data/gapminder_population.xlsx", index_col = 0, engine='openpyxl')
life = pd.read_excel("../data/gapminder_lifeexpectancy.xlsx", index_col=0, engine='openpyxl')

# %%
df = transform_data(fert, population, life)
df = missing_data(df)

# %%
#Visualize subset of e.g 3 countries (Canada, Ghana, Germany)
df_subset = df.loc[df['country'].isin(['Canada', 'Ghana', 'Germany'])]
df_subset
# Out:
#        country  year  fertility_rate  total_population  life_expectancy
# 37      Canada  1950            3.43        13736997.0            68.26
# 82     Germany  1950            2.07        69786246.0            66.91
# 83       Ghana  1950            6.37         4980878.0            41.37
# 296     Canada  1951            3.47        14099994.0            68.53
# 341    Germany  1951            2.08        70111671.0            67.08
# ...        ...   ...             ...               ...              ...
# 16658  Germany  2014            1.43        80646262.0            80.70
# 16659    Ghana  2014            3.80        26786598.0            64.80
# 16872   Canada  2015            1.68        35939927.0            81.70
# 16917  Germany  2015            1.44        80688545.0            80.80
# 16918    Ghana  2015            3.74        27409893.0            65.30
#
# [198 rows x 5 columns]

# %%
sns.lineplot(x='year', y='fertility_rate', hue='country',
            data=df_subset)
plt.show()

# %%
sns.lineplot(x='year', y='total_population', hue='country',
            data=df_subset)
plt.show()

# %%
sns.lineplot(x='year', y='life_expectancy', hue='country',
            data=df_subset)
plt.show()

# %%
# Have a look at some statistics
df.corr()
# Out:
#                   fertility_rate  total_population  life_expectancy
# fertility_rate          1.000000         -0.098195        -0.805566
# total_population       -0.098195          1.000000         0.029944
# life_expectancy        -0.805566          0.029944         1.000000

# %%
df.min()
# Out:
# country             Afghanistan
# year                       1950
# fertility_rate             0.84
# total_population          13766
# life_expectancy            13.2
# dtype: object

# %%
df.max()
# Out:
# country                Zimbabwe
# year                       2015
# fertility_rate             9.22
# total_population    1.37605e+09
# life_expectancy           83.73
# dtype: object

# %%
# We are going to create an animated scatterplot for each yearshowing the correlation between 
# life expectancy and fertility, with the size of the symbols represented by the population
my_dpi=96
df_subset['country']=pd.Categorical(df_subset['country'])
#df_subset = df_subset[ df_subset.year >= 1960 ]
for i in df_subset.year.unique():    
    fig = plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)
    tmp=df_subset[ df_subset.year == i ]
    plt.scatter(tmp['life_expectancy'], tmp['fertility_rate'] , s=tmp['total_population']/100000 , 
    c=tmp['country'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
    #plt.yscale('log')
    plt.xlabel("life_expectancy")
    plt.ylabel("fertility_rate")
    plt.title("Year: "+str(i) )
    plt.axis((0, 100, 0, 10))
    filename='Gapminder'+str(i)+'.png'
    plt.savefig("../Images/Gapminder_" +str(i), dpi=96)
    plt.gca()
# Out:
# C:\Users\pbamo\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\pbamo\anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys

# %%
import imageio

images = []

for i in range(1960, 2015):
    df_subset = '../Images/Gapminder_{}.png'.format(i)
    images.append(imageio.imread(df_subset))

imageio.mimsave('../Images/Gapminder.gif', images, fps=5)
